# %%
pip install googletrans==4.0.0-rc1

# %% [markdown]
# ### 필요사항
# - 번역 정확도 높이기
# - 파파고 번역기 api 사용후 글 확인 (일본, 프랑스)
# - 전처리 과정

# %%
import nltk
#nltk.download("book", quiet=True)
#from nltk.book import *
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.tag import pos_tag
# from textblob import TextBlob
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
import googletrans

def Url(search):
  #  url_temp = 'https://www.google.com/search?q=%7Bsearch%7D&tbm=nws%27.format(search=search)
#     url_temp = 'https://search.mt.co.kr/searchNewsList.html?srchFd=TOTAL&range=IN&reSrchFlag=&preKwd=&search_type=m&kwd=%7Bsearch%7D&bgndt=20190401&enddt=20190930&category=MTNW&sortType=allwordsyn&subYear=&category=MTNW&subType=mt%27.format(search=search)
    for pageNo in range(1,10,10):
        url = url_temp + "&start={pageNo}".format(pageNo=pageNo)
        driver = webdriver.Chrome()
        driver.get(url)

        html = driver.page_source
        soup = BeautifulSoup(html)

        news_urls = []
        # 검색 했을 때 제목과 breadcrumbs, 접속주소를 가져올 것이다.
        # #search>div>div>div>div>div
        list = soup.select('#search .MjjYud>div>div>div')
        if not list:
            print("없어어어어어어엉~")
            break

        for i in list:
            if i.select_one('div>a>div>div:nth-child(2)>div:nth-child(2)'):
                news_urls.append(i.select_one(".WlydOe").get("href"))
#                 print(i.select_one('div>a>div>div:nth-child(2)>div:nth-child(2)').attrs)
#                 print(i.select_one('.iRPxbe>div:nth-child(2)').text)
            else:
                print("text 속성 없어어어어어어엉~")
        print(news_urls)
        if not news_urls:
            break

# %%
def news(news_urls):
    translator = googletrans.Translator() # 번역하는 함수
    for url_no in news_urls:
        print(url_no)
        driver = webdriver.Chrome()
        driver.get(url_no)
        html = driver.page_source
        soup = BeautifulSoup(html)

        str = "" # p 태그의 내용을 담는 변수
        result = "" # 영어로 변환하여 저장할 변수
        for text in soup.findAll("p"): # soup의 모든 p 태그를 처리
            str += text.get_text() + "\n" 
            if(len(str)>1000): # 번역을 위해서 str의 글자수가 1000자보다 넘을 경우에만 번역 실행
                # 영어로 변환, 정확도를 위해서 어떤 언어인지 알려주는 것도 좋음
                # ref: https://coding-kindergarten.tistory.com/98
#                 result1 = translator.translate(str, dest='ko')
                print(str)
                result += translate(str)
#                 result += result1.text.replace(" -", "-").replace("- ", "-")
                str = ""
        
        # 마지막으로 남아있는 문장 번역
        if str !="":
            result += translate(str)
#             result1 = translator.translate(str, dest='ko')
#             result += result1.text.replace(" -", "-").replace("- ", "-")
        return result

# %%
import json
import os
import sys
import urllib.request
client_id = "6yrWrXVyj5VaRKnqi_fv"
client_secret = "i9h16BCiqz"

url = "https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

def translate(str):
    encText = urllib.parse.quote(str)
    data = "source=ja&target=en&text=" + encText
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        result = json.loads(response_body.decode('utf-8'))
        return result['message']['result']['translatedText']
#         print(result['message']['result']['translatedText'])
    #     print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)

# %%
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time

def news(news_urls):
    translator = googletrans.Translator() # 번역하는 함수
    for url_no in news_urls:
        print(url_no)
        options = webdriver.ChromeOptions()  
#         options.add_argument('headless')              # Headless 
#         options.add_argument("--window-size=800,600") # window-size -> 기본 : 1920,1080
#         options.add_argument("disable-gpu")           # browser gpu stop
        # 실제 브라우저처럼 head 정보 입력(크롤링 차단 방지)
#         options.add_argument("User-Agent:  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) \
#                              AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36")
        options.add_argument("lang=ko_KR")      
#         options.add_argument("disable-gpu")
        # 혹은 options.add_argument("--disable-gpu")

        
        driver = webdriver.Chrome('chromedriver', chrome_options=options)
        action = webdriver.ActionChains(driver)
        action.send_keys(Keys.SHIFT, Keys.F10, 't').perform()
        driver.get(url_no)
        pyautogui.hotkey('shift', 'F10')
        for i in range(8):
            pyautogui.hotkey('down')
        pyautogui.hotkey('enter')
        
        time.sleep(5)
        html = driver.page_source
        soup = BeautifulSoup(html)

        str = "" # p 태그의 내용을 담는 변수
        for text in soup.findAll("p"): # soup의 모든 p 태그를 처리
            str += text.get_text()
        return str

# %%
text = news(['https://www.kdramastars.com/articles/126325/20220820/k-dramas-north-south-korea-money-heist-korea-crash-landing-on-you.htm'])
text
# Out:
# https://www.kdramastars.com/articles/126325/20220820/k-dramas-north-south-korea-money-heist-korea-crash-landing-on-you.htm
# C:\Users\multicampus\AppData\Local\Temp\ipykernel_40644\2652359399.py:22: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('chromedriver', chrome_options=options)
# '\n        To enjoy our website, you\'ll need to enable JavaScript in your web browser. Please click here to learn how.\n    K-dramas managed to cover the stories of North Korea despite the ongoing war between the two countries.\xa0Interestingly, the remarkable and iconic series in Hallyu shows a glimpse of life in North Korea.\xa0From rom-com to crime thriller series, these 5 K-dramas feature stories about North and South Korea.\xa0Netflix introduced the Korean remake of the hit Spanish series "La Casa de Papel" or "Money Heist" created by Álex Pina.\xa0After five successful seasons, the tv show was remade to "Money Heist: Korea - Joint Economic Area" starring Yoo Ji Tae as the Professor, "Squid Game" star Park Hae Soo as Berlin, Jeon Jong Seo as Tokyo, and many more.\xa0The Korean remake follows a hostage crisis set in a unified Korean Peninsula.From hostages, employees, gang members, and even the task force are mixed from both North and South.\xa0While the first part, containing 6 episodes, was released on June 24, "Money Heist: Korea - Joint Economic Area" is predicted to premiere in the final quarter of 2022.\xa0Of course, the rundown of K-dramas with North and South Korean stories will not be complete without "Crash Landing on You" starring Son Ye Jin and Hyun Bin.\xa0Undeniably one of the most hyped series in 2019, the drama follows the story of South Korean heiress Yoon Seri (Son Ye Jin) who accidentally landed on the DMZ that runs across the Korean Peninsula.\xa0Here, she unexpectedly meets a North Korean soldier, Captain Ri Jung Hyuk who agrees to help her return to her hometown.\xa0However, the two were faced with challenges as the tension between the two countries continues. Amid this, Yoon Seri and Captain Ri didn\'t realize that they were falling for one another.Headlined by Lee Seung Gi, Ha Ji Won, and Jo Jung Suk, the 2012 rom-com K-drama "The King 2 Hearts" depicts the collaboration between two influential people of North Korea and South Korea.\xa0Ha Ji Woon took the role of North Korea\'s elite special forces unit instructor and the daughter of a high-ranking military official Kim Hang A who was sent to a joint military collaboration.\xa0She then meets South Korea\'s crown prince Lee Jae Ha. Despite the love-hate relationship, the duo ended up being engaged but encountered a tough situation after they had to choose between love and loyalty.\xa0Another 2012 K-drama that highlights stories between the two counties is "Korean Peninsula."The 18-part episode stars Hwang Jung Min as South Korean scientist Seo Myung Joon who falls in love with North Korean scientist Im Jin Jae, played by Kim Jung Eun.\xa0The 2014 medical K-drama stars Lee Jong Suk as Park Hoon, the genius heart surgeon from North Korea.\xa0However, when he was a child, he and his father were kidnapped by North Korea, and trained to become a doctor in his new country.\xa0Due to an incident, he returned to South Korea and began working in a top-tier hospital, Myeongwoo University Hospital.\xa0Join KDrama Stars Email Update'

# %%
print(text)
# Out:
#         To enjoy our website, you'll need to enable JavaScript in your web browser. Please click here to learn how.
#     K-dramas managed to cover the stories of North Korea despite the ongoing war between the two countries. Interestingly, the remarkable and iconic series in Hallyu shows a glimpse of life in North Korea. From rom-com to crime thriller series, these 5 K-dramas feature stories about North and South Korea. Netflix introduced the Korean remake of the hit Spanish series "La Casa de Papel" or "Money Heist" created by Álex Pina. After five successful seasons, the tv show was remade to "Money Heist: Korea - Joint Economic Area" starring Yoo Ji Tae as the Professor, "Squid Game" star Park Hae Soo as Berlin, Jeon Jong Seo as Tokyo, and many more. The Korean remake follows a hostage crisis set in a unified Korean Peninsula.From hostages, employees, gang members, and even the task force are mixed from both North and South. While the first part, containing 6 episodes, was released on June 24, "Money Heist: Korea - Joint Economic Area" is predicted to premiere in the final quarter of 2022. Of course, the rundown of K-dramas with North and South Korean stories will not be complete without "Crash Landing on You" starring Son Ye Jin and Hyun Bin. Undeniably one of the most hyped series in 2019, the drama follows the story of South Korean heiress Yoon Seri (Son Ye Jin) who accidentally landed on the DMZ that runs across the Korean Peninsula. Here, she unexpectedly meets a North Korean soldier, Captain Ri Jung Hyuk who agrees to help her return to her hometown. However, the two were faced with challenges as the tension between the two countries continues. Amid this, Yoon Seri and Captain Ri didn't realize that they were falling for one another.Headlined by Lee Seung Gi, Ha Ji Won, and Jo Jung Suk, the 2012 rom-com K-drama "The King 2 Hearts" depicts the collaboration between two influential people of North Korea and South Korea. Ha Ji Woon took the role of North Korea's elite special forces unit instructor and the daughter of a high-ranking military official Kim Hang A who was sent to a joint military collaboration. She then meets South Korea's crown prince Lee Jae Ha. Despite the love-hate relationship, the duo ended up being engaged but encountered a tough situation after they had to choose between love and loyalty. Another 2012 K-drama that highlights stories between the two counties is "Korean Peninsula."The 18-part episode stars Hwang Jung Min as South Korean scientist Seo Myung Joon who falls in love with North Korean scientist Im Jin Jae, played by Kim Jung Eun. The 2014 medical K-drama stars Lee Jong Suk as Park Hoon, the genius heart surgeon from North Korea. However, when he was a child, he and his father were kidnapped by North Korea, and trained to become a doctor in his new country. Due to an incident, he returned to South Korea and began working in a top-tier hospital, Myeongwoo University Hospital. Join KDrama Stars Email Update

# %%
url_no = 'https://www.kdramastars.com/articles/126325/20220820/k-dramas-north-south-korea-money-heist-korea-crash-landing-on-you.htm'
driver = webdriver.Chrome()
driver.get(url_no)
# pyautogui.hotkey('shift', 'F10')
# for i in range(8):
#     pyautogui.hotkey('down')
# pyautogui.hotkey('enter')

# %%
driver.get('https://trends.tribunnews.com/2022/09/06/sinopsis-crash-landing-on-you-kisah-wanita-nyasar-ke-korea-utara-dibintangi-son-ye-jin-hyun-bin')

# %%
import spacy
import re

nlp = spacy.load('en_core_web_md')
# text = 'Yuh-jung Youn won the Oscar for best supporting actress for her performance in "Minari" on Sunday and made history by becoming the first Korean actor to win an Academy Award.'
# text = 'Korean drama "U-Yongu Lawyer is a genius skin", which depicts a new lawyer with autism spectrums, growing, and has a great response in Japan.'
# text = 'In response to the statement of Lee Sanbek, the drama official commented on the Korean media carefully commented on the Korean media. However, "The scriptwriter Moon Ji-won and Yu Insok are positive attitude", and the possibilities of Season 2 are certainly talked about among the production teams!'
# text = 'If watching Squid Game means the prospect of playing red light, green light now fills you with nerve-shredding terror rather than fond childhood memories, you aren\t alone.The Korean thriller, which tells the story of debt-ridden people competing for a huge cash prize in a deadly series of children\s games, has become Netflix\s biggest ever series launch - streamed by 111 million users in its first 28 days.In doing so it knocked Bridgerton off the top spot, making clear that Korean dramas have most certainly been given the green light by audiences worldwide. So, how can we understand this rise, and what are some of the other K-dramas to look out for if you\'re a new convert?'

# text = re.sub('"[^a-zA-Z]"', ' ', text)
text = text.replace('\"', "")
text = text.lower()
doc = nlp(text)

noun_chunks = doc.noun_chunks

print("=="*40)
str_format = "{:>30}{:>15}{:>15}{:>20}"
print(str_format.format('Text', 'Root Text', 'Root Dep', 'Root Head Text'))
print("=="*40)

data = []
for chunk in doc.noun_chunks:
    data.append(chunk.text)
    print(str_format.format(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text))
# Out:
# ================================================================================
#                           Text      Root Text       Root Dep      Root Head Text
# ================================================================================
#                    our website        website           dobj               enjoy
#                            you            you          nsubj                need
#                     javascript     javascript           dobj              enable
#               your web browser        browser           pobj                  in
#             k-드라마는 남북 전쟁이 계속되고           계속되고           pobj
#
#                  불구하고 북한의 이야기를           이야기를          appos                있음에도
#                          있었습니다          있었습니다           pobj                  다룰
#              흥미롭게도 놀랍고 상징적인 한류             한류           ROOT                  한류
#                           시리즈는           시리즈는          appos                  한류
#                      북한의 삶을 엿볼             엿볼          appos                  한류
#                           있습니다           있습니다          appos                  한류
#                      스릴러 시리즈까지          시리즈까지           pobj                  범죄
#                     5개의 k-드라마는           드라마는          nsubj                남북한에
#                             대한             대한           dobj                남북한에
#                      이야기를 다룹니다           다룹니다           dobj                남북한에
#                 넷플릭스(netflix)는 넷플릭스(netflix)는          nsubj                 알렉스
#                 피나(alex pina)가         pina)가           dobj                 알렉스
#                            히트작            히트작           dobj                스페인의
#    '라 카사 드 파펠(la casa de papel          papel           dobj                스페인의
#       또는 '머니 습격(money heist)'의       heist)'의           ROOT            heist)'의
#                           리메이크           리메이크           pobj                  한국
#                       작품을 소개했다           소개했다           pobj                  한국
#                            5개의            5개의          nsubj                성공적인
#                       시즌 후에 tv             tv          nsubj                  쇼는
#                            유지태            유지태           dobj                  쇼는
#            교수, 오징어 게임의 박해수(베를린        박해수(베를린          appos                  쇼는
#                             습격             습격           pobj                   돈
#                           지역으로           지역으로           pobj                  경제
#                      리메이크되었습니다      리메이크되었습니다           dobj                 출연한
#               한국 리메이크는 통일 한반도를           한반도를          nsubj                  인질
#                           배경으로           배경으로           dobj                한반도를
#                            위기를            위기를           dobj                  인질
#                    따릅니다.인질에서부터    따릅니다.인질에서부터          appos                 위기를
#                     태스크포스까지 남과             남과           dobj                 심지어
#                           있습니다           있습니다           pobj                  섞여
#                             지난             지난           ROOT                  지난
#                             6월             6월           pobj                  지난
#                            가운데            가운데           dobj                 공개된
#                           예정이다           예정이다           dobj                 방송될
#                        물론 손예진과           손예진과           ROOT                손예진과
#                        현빈이 주연을            주연을          nsubj                이야기가
#                불시착'이 없었다면 남북한의           남북한의          nsubj                이야기가
#                             담긴             담긴           dobj                이야기가
#               k-드라마의 줄거리는 완성되지           완성되지           dobj                이야기가
#                        않았을 것이다            것이다          appos                완성되지
#                             과대             과대           pobj                  가장
#                            광고된            광고된          nsubj                 시리즈
#                드라마는 한반도를 가로지르는          가로지르는          nsubj                dmz에
#                        우연히 착륙한            착륙한          appos                dmz에
#        상속녀 윤세리(손예진)의 이야기를 따릅니다           따릅니다           pobj                  한국
#              그곳에서 그녀는 고향으로 돌아갈            돌아갈          nsubj                 동의한
#                             북한             북한           dobj                 동의한
#          군인 리정혁 대위를 예기치 않게 만난다            만난다           dobj                 동의한
#                            사람은            사람은          nsubj                봉착했다
#                              리              리          appos                윤세리와
#                        대위는 자신이            자신이          appos                윤세리와
#                   서로에게 빠지고 있다는            있다는           dobj                윤세리와
#                        못했다.이승기        못했다.이승기           pobj                 깨닫지
#                          , 하지원            하지원          appos                윤세리와
#                       조정석이 주연을            주연을          nsubj                 로맨틱
#        코미디 k-드라마 더 킹 투하츠는 남북한의           남북한의          nsubj                  있는
#                            영향력            영향력           pobj                   두
#                            인물의            인물의           dobj                  있는
#                       그린 작품입니다          작품입니다           ROOT               작품입니다
#                           하지운은           하지운은          nsubj                 북한의
#      엘리트 특수부대 교관이자 합동군사부대에 파견된            파견된           dobj                 북한의
#                            맡았다            맡았다           pobj                  역을
#                            그녀는            그녀는           dobj                 그리고
#                   왕세자 이재하를 만난다            만난다           dobj                 그리고
#                  애증의 관계에도 불구하고           불구하고          nsubj                 사랑과
#                            사람은            사람은           pobj                   두
#                          약혼했지만          약혼했지만           pobj                  결국
#              하는 어려운 상황에 직면했습니다         직면했습니다           dobj                선택해야
#                두 나라의 이야기를 조명하는           조명하는          nsubj                드라마는
#             황정민은 남한의 과학자 서명준으로          서명준으로           dobj        한반도입니다.18부작의
#                        북한의 과학자            과학자          nsubj           임진재(김정은)와
#                            사랑에            사랑에           dobj           임진재(김정은)와
#                            빠진다            빠진다           dobj           임진재(김정은)와
#                   k-드라마에서 이종석은           이종석은           pobj                  의료
#                         북한의 천재             천재          appos                이종석은
#                     박훈으로 출연합니다          출연합니다           attr                  외과
#                         그러나 그가             그가          nsubj                납치되어
#               어렸을 때 그와 그의 아버지는           아버지는           pobj                  그가
#                            새로운            새로운           dobj                납치되어
#                           나라에서           나라에서           dobj                납치되어
#            의사가 되기 위해 훈련을 받았습니다          받았습니다           dobj                납치되어
#    귀국한 그는 명우대병원 일류병원에서 일을 시작했다           시작했다           dobj                 계기로
#      kdrama stars email update         update           dobj                join

# %%
text
# Out:
# ['reproduction', 'n']

# %%
from nltk.corpus import stopwords

data
result = []
for token in data:
    result.append(token.split())

# 불용어 제거
stops = set(stopwords.words('english'))
for data in result:
    for word in data:
        if word in stops:
            data.remove(word)

# %%
import nltk

tag=[nltk.pos_tag(data) for data in result if data]
print(tag)
# Out:
# [[('website', 'NN')], [('javascript', 'NN')], [('web', 'NNS'), ('browser', 'NN')], [('k-드라마는', 'JJ'), ('남북', 'NNP'), ('전쟁이', 'NNP'), ('계속되고', 'NN')], [('불구하고', 'JJ'), ('북한의', 'NNP'), ('이야기를', 'NN')], [('있었습니다', 'NN')], [('흥미롭게도', 'JJ'), ('놀랍고', 'NNP'), ('상징적인', 'NNP'), ('한류', 'NN')], [('시리즈는', 'NN')], [('북한의', 'JJ'), ('삶을', 'NNP'), ('엿볼', 'NN')], [('있습니다', 'NN')], [('스릴러', 'NN'), ('시리즈까지', 'NN')], [('5개의', 'CD'), ('k-드라마는', 'NN')], [('대한', 'NN')], [('이야기를', 'NN'), ('다룹니다', 'NN')], [('넷플릭스(netflix)는', 'NN')], [('피나(alex', 'JJ'), ('pina)가', 'NN')], [('히트작', 'NN')], [("'라", 'POS'), ('카사', 'NN'), ('드', 'NNP'), ('파펠(la', 'NNP'), ('casa', 'NN'), ('de', 'FW'), ('papel', 'NN')], [('또는', 'JJ'), ("'머니", 'POS'), ('습격(money', 'NN'), ("heist)'의", 'NN')], [('리메이크', 'NN')], [('작품을', 'NN'), ('소개했다', 'NN')], [('5개의', 'CD')], [('시즌', 'JJ'), ('후에', 'NNP'), ('tv', 'NN')], [('유지태', 'NN')], [('교수,', 'JJ'), ('오징어', 'NNP'), ('게임의', 'NNP'), ('박해수(베를린', 'NN')], [('습격', 'NN')], [('지역으로', 'NN')], [('리메이크되었습니다', 'NN')], [('한국', 'JJ'), ('리메이크는', 'NNP'), ('통일', 'NNP'), ('한반도를', 'NN')], [('배경으로', 'NN')], [('위기를', 'NN')], [('따릅니다.인질에서부터', 'NN')], [('태스크포스까지', 'NN'), ('남과', 'NN')], [('있습니다', 'NN')], [('지난', 'NN')], [('6월', 'CD')], [('가운데', 'NN')], [('예정이다', 'NN')], [('물론', 'NN'), ('손예진과', 'NN')], [('현빈이', 'NN'), ('주연을', 'NN')], [("불시착'이", 'JJ'), ('없었다면', 'NNP'), ('남북한의', 'NN')], [('담긴', 'NN')], [('k-드라마의', 'JJ'), ('줄거리는', 'NN'), ('완성되지', 'NN')], [('않았을', 'NN'), ('것이다', 'NN')], [('과대', 'NN')], [('광고된', 'NN')], [('드라마는', 'JJ'), ('한반도를', 'NNP'), ('가로지르는', 'NN')], [('우연히', 'NN'), ('착륙한', 'NN')], [('상속녀', 'JJ'), ('윤세리(손예진)의', 'NNP'), ('이야기를', 'NNP'), ('따릅니다', 'NN')], [('그곳에서', 'JJ'), ('그녀는', 'NNP'), ('고향으로', 'NNP'), ('돌아갈', 'NN')], [('북한', 'NN')], [('군인', 'JJ'), ('리정혁', 'NNP'), ('대위를', 'NNP'), ('예기치', 'NNP'), ('않게', 'NNP'), ('만난다', 'NN')], [('사람은', 'NN')], [('리', 'NN')], [('대위는', 'NN'), ('자신이', 'NN')], [('서로에게', 'JJ'), ('빠지고', 'NNP'), ('있다는', 'NN')], [('못했다.이승기', 'NN')], [(',', ','), ('하지원', 'NN')], [('조정석이', 'NN'), ('주연을', 'NN')], [('코미디', 'JJ'), ('k-드라마', 'JJ'), ('더', 'NN'), ('킹', 'NNP'), ('투하츠는', 'NNP'), ('남북한의', 'NN')], [('영향력', 'NN')], [('인물의', 'NN')], [('그린', 'NN'), ('작품입니다', 'NN')], [('하지운은', 'NN')], [('엘리트', 'JJ'), ('특수부대', 'NNP'), ('교관이자', 'NNP'), ('합동군사부대에', 'NNP'), ('파견된', 'NN')], [('맡았다', 'NN')], [('그녀는', 'NN')], [('왕세자', 'JJ'), ('이재하를', 'NNP'), ('만난다', 'NN')], [('애증의', 'JJ'), ('관계에도', 'NNP'), ('불구하고', 'NN')], [('사람은', 'NN')], [('약혼했지만', 'NN')], [('하는', 'JJ'), ('어려운', 'NNP'), ('상황에', 'NNP'), ('직면했습니다', 'NN')], [('두', 'JJ'), ('나라의', 'NNP'), ('이야기를', 'NNP'), ('조명하는', 'NN')], [('황정민은', 'JJ'), ('남한의', 'NNP'), ('과학자', 'NNP'), ('서명준으로', 'NN')], [('북한의', 'NN'), ('과학자', 'NN')], [('사랑에', 'NN')], [('빠진다', 'NN')], [('k-드라마에서', 'JJ'), ('이종석은', 'NN')], [('북한의', 'NN'), ('천재', 'NN')], [('박훈으로', 'NN'), ('출연합니다', 'NN')], [('그러나', 'NN'), ('그가', 'NN')], [('어렸을', 'JJ'), ('때', 'NNP'), ('그와', 'NNP'), ('그의', 'NNP'), ('아버지는', 'NN')], [('새로운', 'NN')], [('나라에서', 'NN')], [('의사가', 'JJ'), ('되기', 'NNP'), ('위해', 'NNP'), ('훈련을', 'NNP'), ('받았습니다', 'NN')], [('귀국한', 'JJ'), ('그는', 'NNP'), ('명우대병원', 'NNP'), ('일류병원에서', 'NNP'), ('일을', 'NNP'), ('시작했다', 'NN')], [('kdrama', 'NN'), ('stars', 'NNS'), ('email', 'VBP'), ('update', 'NN')]]

# %% [markdown]
# - pos: n(명사), v(동사), a(형용사), r(부사), satellite adjectives(s)
# - NN, NNS, NNP, NNPS (n)
# - VB, VBD, VBG, VBN, VBP, VBZ (v)
# - RB, RBR, RBS (r)
# - JJ (a)

# %%
n = {'NN', 'NNS', 'NNP', 'NNPS'}
v = {'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'}
r = {'RB', 'RBR', 'RBS'}
a = {'JJ'}

# %%
list(tag)
# Out:
# [[('perpetrator', 'NN')],
#  [('movie', 'NN')],
#  [('utamaru', 'NN')],
#  [('problem', 'NN')],
#  [('movie', 'NN')],
#  [('gifts', 'NNS')],
#  [('important', 'JJ'), ('people', 'NNS')],
#  [('disaster', 'NN'),
#   ('prevention', 'NN'),
#   ('[emergency', 'NN'),
#   ('support', 'NN')],
#  [('pakistan', 'RB'), ('flood', 'NN'), ('damage', 'NN')],
#  [('right', 'RB'), ('knowledge', 'NN')],
#  [('preparation', 'NN')],
#  [('evacuation', 'NN'), ('drills', 'NNS')],
#  [('typhoons', 'NNS')],
#  [('torrential', 'JJ'), ('rains', 'NNS')],
#  [('3', 'CD'), ('minutes', 'NNS'), ('keyword', 'VBD')],
#  [('many', 'JJ'), ('coupons', 'NNS')],
#  [('ids', 'NNS')],
#  [('javascript', 'NN')],
#  [('the', 'DT'), ('functions', 'NNS')],
#  [('yahoo', 'NN')],
#  [('news', 'NN')],
#  [('javascript', 'NN'), ('settings', 'NNS')],
#  [('javascript', 'NN'), ('settings', 'NNS')],
#  [('8/19', 'CD'), ('(fri)', 'JJ'), ('19:20', 'CD'), ('distribution', 'NN')],
#  [('new', 'JJ'), ('lawyer', 'NN')],
#  [('autism', 'NN'), ('spectrums', 'NNS')],
#  [('huge', 'JJ'), ('response', 'NN')],
#  [('japan', 'NN')],
#  [('great', 'JJ'), ('response', 'NN')],
#  [('japan', 'NN')],
#  [('drama', 'NN')],
#  [('u', 'NN')],
#  [('-', ':')],
#  [('yongu', 'NN')],
#  [('genius', 'NN'), ('skin', 'NN')],
#  [('[photo', 'NN')],
#  [('popular', 'JJ'), ('korean', 'JJ'), ('actress', 'NN')],
#  [('this', 'DT')],
#  [('work', 'NN')],
#  [('maximum', 'JJ'), ('audience', 'NN'), ('rating', 'NN')],
#  [('17.5', 'CD'), ('%', 'NN')],
#  [('august', 'NN')],
#  [('possibility', 'NN')],
#  [('season', 'NN')],
#  [('spoilers', 'NNS')],
#  [('article', 'NN')],
#  [('report', 'NN')],
#  [('korean', 'JJ'), ('media', 'NNS')],
#  [('august', 'NN')],
#  [('lee', 'NN'), ('sanbek', 'NN')],
#  [('representative', 'NN')],
#  [('story', 'NN')],
#  [('production', 'NN'), ('company', 'NN')],
#  [('u-yong-woo', 'JJ')],
#  [('genius', 'NN'), ('skin', 'NN')],
#  [('season', 'NN')],
#  [('possibility', 'NN')],
#  [('sequel', 'NN')],
#  [('schedule', 'NN')],
#  [('casts', 'NNS')],
#  [('production', 'NN'), ('teams', 'NNS')],
#  [('discussions', 'NNS')],
#  [('goal', 'NN')],
#  [('90', 'CD'), ('%', 'NN')],
#  [('crew', 'NN')],
#  [('major', 'JJ'), ('change', 'NN')],
#  [('remarks', 'NNS')],
#  [('instagram', 'NN')],
#  [('/@booboo2injo', 'NN'), ('lee', 'NN'), ('sanbek', 'NN')],
#  [('drama', 'NN'), ('officials', 'NNS')],
#  [('korean', 'JJ'), ('media', 'NNS')],
#  [('scriptwriter', 'NN')],
#  [('moon', 'NN')],
#  [('positive', 'JJ'), ('attitude', 'NN')],
#  [('possibilities', 'NNS')],
#  [('season', 'NN')],
#  [('production', 'NN'), ('teams', 'NNS')],
#  [('cast', 'NN'), ('members', 'NNS')],
#  [('than', 'IN'), ('90', 'CD'), ('%', 'NN')],
#  [('time', 'NN')],
#  [('concrete', 'JJ'), ('discussions', 'NNS')],
#  [('kang', 'NN'), ('teo', 'NN')],
#  [('role', 'NN')],
#  [('lee', 'NN'), ('juno', 'NN')],
#  [('big', 'JJ'), ('break', 'NN')],
#  [('work', 'NN')],
#  [('office', 'NN')],
#  [('man', 'NN')],
#  [('creation', 'NN')],
#  [('concrete', 'NN')],
#  [('content', 'NN')],
#  [('content', 'NN')],
#  [('instagram/@channel.ena.d', 'NN')],
#  [('kang', 'VB'), ('gi-yeon', 'NN')],
#  [('role', 'NN')],
#  [('boss', 'NN'), ('jung', 'NN'), ('myeong-suk', 'NN')],
#  [('u-young', 'JJ'), ('woo', 'NN')],
#  [('interview', 'NN')],
#  [('korean', 'JJ'), ('media', 'NNS')],
#  [('willingness', 'NN')],
#  [('.', '.'), ('instagram', 'NN')],
#  [('season', 'NN')],
#  [('atmosphere', 'RB')],
#  [('drama', 'NN'), ('shooting', 'VBG'), ('site', 'NN')],
#  [('feeling', 'VBG')],
#  [('course', 'NN')],
#  [('end', 'NN')],
#  [('appearance', 'NN')],
#  [('ju', 'NN'), ('jong', 'NN'), ('hyuk', 'NN')],
#  [('good', 'JJ'), ('colleague', 'NN')],
#  [('kwon', 'NNS'), ('minu', 'NNS')],
#  [('rivalry', 'NN')],
#  [('radio', 'NN')],
#  [('19th', 'CD')],
#  [('possibility', 'NN')],
#  [('season', 'NN')],
#  [('_', 'NN')],
#  [('final', 'JJ'), ('script', 'NN')],
#  [('season', 'NN')],
#  [('work', 'NN')],
#  [('web', 'NN'), ('comics', 'NNS')],
#  [('musicals', 'NNS')],
#  [('sequel', 'NN')],
#  [('cast', 'NN')],
#  [('season', 'NN')],
#  [('article', 'NN')],
#  [("'s", 'POS')],
#  [('reaction', 'NN')],
#  [('u', 'NN')],
#  [('-yong-woo', 'NN')],
#  [('genius', 'NN')],
#  [('skin', 'NN'), ('kang', 'VBD'), ('gi-yeon', 'JJ'), ('response', 'NN')],
#  [('work', 'NN')],
#  [('kstyle9/1', 'NN')],
#  [('thu', 'NN')],
#  [('kang', 'NN'), ('teo', 'NN')],
#  [('september', 'NN')],
#  [('enlistment', 'NN')],
#  [('fan', 'NN'), ('meeting', 'NN')],
#  [('u-yong-woo', 'JJ')],
#  [('genius', 'NN'), ('skin', 'NN')],
#  [('army', 'NN'), ('kstyle9/1', 'NN')],
#  [('(thu)', 'RB'), ('9:36', 'CD'), ('kstyle9/5', 'NNS')],
#  [('korean', 'JJ'), ('dora', 'NNS'), ('u-yong-woo', 'JJ')],
#  [('genius', 'NN')],
#  [('skin', 'NN'), ('global', 'JJ'), ('1st', 'CD'), ('place', 'NN')],
#  [('encount8/31', 'NN')],
#  [('20:13', 'CD'), ('chubby', 'NN')],
#  [('short', 'JJ'), ('stature', 'NN')],
#  [('armpit', 'NN'), ('hair', 'NN')],
#  [('fashion', 'NN'), ('magazines', 'NNS')],
#  [('models', 'NNS')],
#  [('diversity', 'NN'), ('era', 'NN')],
#  [('subdivision', 'NN')],
#  [('diversity', 'NN'), ('erika', 'FW'), ('toda', 'NN')],
#  [('actress', 'NN'), ('absence', 'NN')],
#  [('next', 'JJ'),
#   ("year's", 'NN'),
#   ('january', 'JJ'),
#   ('dora', 'NNS'),
#   ('return', 'VBP'),
#   ('theory', 'NN')],
#  [('certain', 'JJ'), ('circumstances', 'NNS')],
#  [('real', 'JJ'), ('face', 'NN'), ('shot', 'NN')],
#  [('gold', 'NN'),
#   ('bomb', 'NN'),
#   ('/', 'NNP'),
#   ('barrel', 'NN'),
#   ('sake', 'NN'),
#   ('buns', 'NNS')],
#  [('glasses', 'NNS')],
#  [('perm', 'NN')],
#  [('extremely', 'RB'),
#   ('handsome', 'JJ'),
#   ('beautiful', 'JJ'),
#   ('line', 'NN')],
#  [('<megumi', 'NN'), ('matsumoto', 'NN')],
#  [('time', 'NN')],
#  [('marriage', 'NN')],
#  [('yuzo', 'NN'), ("kayama's", 'VBZ'), ('wife', 'NN')],
#  [('letter', 'NN')],
#  [('female', 'NN'), ('fans', 'NNS')],
#  [('couple', 'NN'), ('popular', 'JJ'), ('cup', 'NN'), ('noodles', 'NNS')],
#  [("tetsuko's", 'NN'), ('room', 'NN'), ('human', 'NN')],
#  [('food', 'NN')],
#  [('egashira', 'NN')],
#  [('bad', 'JJ'), ('reputation', 'NN')],
#  [('co-star', 'JJ'), ('line', 'NN'), ('block', 'NN')],
#  [('toyota', 'NN')],
#  [('teruyuki', 'NN'),
#   ("kagawa's", 'VBZ'),
#   ('another', 'DT'),
#   ('dangerous', 'JJ'),
#   ('face', 'NN')],
#  [('child-rearing', 'NN'), ('child', 'NN')],
#  [('school', 'NN')],
#  [('word', 'NN')],
#  [('the', 'DT'), ('son', 'NN')],
#  [('shou', 'JJ'), ('fuku-kun', 'NN')],
#  [('crying', 'VBG')],
#  [('reason', 'NN')],
#  [('reason', 'NN')],
#  [('reason', 'NN')],
#  [('reason', 'NN')],
#  [('reason', 'NN')],
#  [('reason', 'NN')],
#  [('face', 'NN')],
#  [('face', 'NN')],
#  [('teen', 'NN')],
#  [('nanase', 'NN'), ('aikawa', 'NN')],
#  [('college', 'NN'), ('student', 'NN')],
#  [('age', 'NN')],
#  [('end', 'NN')],
#  [('year]', 'NN'),
#   ('junju', 'NN'),
#   ('/', 'NNP'),
#   ('ryohei', 'NN'),
#   ('odai', 'NN')],
#  [('new', 'JJ'), ('member', 'NN')],
#  [('one-word', 'JJ'), ('turtle', 'NN')],
#  [('yanus', 'NN')],
#  [("switzerland's", 'JJ'),
#   ('natural', 'JJ'),
#   ('history', 'NN'),
#   ('museum', 'NN')],
#  [('[marriage', 'NN')],
#  [('jun', 'NN'), ('idida', 'NN')],
#  [('hachiya', 'NN'), ('yanami', 'NN'), ('sns', 'NN')],
#  [('anyone', 'NN')],
#  [('person', 'NN')],
#  [('only', 'RB'), ('sexual', 'JJ'), ('harassment', 'NN')],
#  [('assault', 'NN')],
#  [('power', 'NN'), ('harassment', 'NN')],
#  [('kagawa', 'NN')],
#  [('real', 'JJ'), ('face', 'NN')],
#  [('330', 'CD'), ('yen', 'NNS')],
#  [('tax', 'NN')],
#  [('330', 'CD'), ('yen', 'NNS'), ('storm', 'NN')],
#  [('aiba', 'NN')],
#  [('tv', 'NN'),
#   ('animal', 'NN'),
#   ('protection', 'NN'),
#   ('organization', 'NN')],
#  [('full', 'JJ'), ('sentence', 'NN')],
#  [('110', 'CD'), ('yen', 'NNS')],
#  [('tax', 'NN'), ('kaoru', 'NN'), ('yachigusa', 'NN')],
#  [('girl', 'NN')],
#  [('sense', 'NN')],
#  [('life', 'NN')],
#  [('heroine', 'NN')],
#  [('hayao', 'NN'), ('miyazaki', 'NN')],
#  [('heroine', 'NN')],
#  [('hayao', 'NN'), ('miyazaki', 'NN')],
#  [('defective', 'JJ'), ('house', 'NN'), ('leopalace', 'NN')],
#  [('home', 'NN'), ('appliances', 'NNS')],
#  [('suzuki', 'NN'), ('suzuki', 'NN')],
#  [('suzuki', 'NN'), ('toshio', 'NN')],
#  [('110', 'CD'), ('yen', 'NNS')],
#  [('tax', 'NN')],
#  [('assault', 'NN'), ('video', 'NN')],
#  [('power', 'NN'), ('harassment', 'NN'), ('sanyo', 'NN')],
#  [('sanyo', 'NN')],
#  [('newcomer', 'JJ'), ('male', 'NN'), ('ana', 'NN')],
#  [('naked', 'JJ'), ('dance', 'NN')],
#  [('110', 'CD'), ('yen', 'NNS')],
#  [('tax', 'NN'), ('copyright', 'NN')],
#  [('©', 'NN'), ('2022', 'CD'), ('hearst', 'NN'), ('fujingaho', 'NN')],
#  [('unauthorized', 'JJ'), ('reproduction', 'NN')]]

# %%
test = []
for tags in tag:
    result = []
    for word in tags:
        word = list(word)
        if word[1] in n:
            word[1] = 'n'
        elif word[1] in v:
            word[1] = 'v'
        elif word[1] in r:
            word[1] = 'r'
        elif word[1] in a:
            word[1] = 'a'
        else:
            word[1] = 'n'
        result.append(word)
    test.append(result)

# %%
test
# Out:
# [[['perpetrator', 'n']],
#  [['movie', 'n']],
#  [['utamaru', 'n']],
#  [['problem', 'n']],
#  [['movie', 'n']],
#  [['gifts', 'n']],
#  [['important', 'a'], ['people', 'n']],
#  [['disaster', 'n'],
#   ['prevention', 'n'],
#   ['[emergency', 'n'],
#   ['support', 'n']],
#  [['pakistan', 'r'], ['flood', 'n'], ['damage', 'n']],
#  [['right', 'r'], ['knowledge', 'n']],
#  [['preparation', 'n']],
#  [['evacuation', 'n'], ['drills', 'n']],
#  [['typhoons', 'n']],
#  [['torrential', 'a'], ['rains', 'n']],
#  [['3', 'n'], ['minutes', 'n'], ['keyword', 'v']],
#  [['many', 'a'], ['coupons', 'n']],
#  [['ids', 'n']],
#  [['javascript', 'n']],
#  [['the', 'n'], ['functions', 'n']],
#  [['yahoo', 'n']],
#  [['news', 'n']],
#  [['javascript', 'n'], ['settings', 'n']],
#  [['javascript', 'n'], ['settings', 'n']],
#  [['8/19', 'n'], ['(fri)', 'a'], ['19:20', 'n'], ['distribution', 'n']],
#  [['new', 'a'], ['lawyer', 'n']],
#  [['autism', 'n'], ['spectrums', 'n']],
#  [['huge', 'a'], ['response', 'n']],
#  [['japan', 'n']],
#  [['great', 'a'], ['response', 'n']],
#  [['japan', 'n']],
#  [['drama', 'n']],
#  [['u', 'n']],
#  [['-', 'n']],
#  [['yongu', 'n']],
#  [['genius', 'n'], ['skin', 'n']],
#  [['[photo', 'n']],
#  [['popular', 'a'], ['korean', 'a'], ['actress', 'n']],
#  [['this', 'n']],
#  [['work', 'n']],
#  [['maximum', 'a'], ['audience', 'n'], ['rating', 'n']],
#  [['17.5', 'n'], ['%', 'n']],
#  [['august', 'n']],
#  [['possibility', 'n']],
#  [['season', 'n']],
#  [['spoilers', 'n']],
#  [['article', 'n']],
#  [['report', 'n']],
#  [['korean', 'a'], ['media', 'n']],
#  [['august', 'n']],
#  [['lee', 'n'], ['sanbek', 'n']],
#  [['representative', 'n']],
#  [['story', 'n']],
#  [['production', 'n'], ['company', 'n']],
#  [['u-yong-woo', 'a']],
#  [['genius', 'n'], ['skin', 'n']],
#  [['season', 'n']],
#  [['possibility', 'n']],
#  [['sequel', 'n']],
#  [['schedule', 'n']],
#  [['casts', 'n']],
#  [['production', 'n'], ['teams', 'n']],
#  [['discussions', 'n']],
#  [['goal', 'n']],
#  [['90', 'n'], ['%', 'n']],
#  [['crew', 'n']],
#  [['major', 'a'], ['change', 'n']],
#  [['remarks', 'n']],
#  [['instagram', 'n']],
#  [['/@booboo2injo', 'n'], ['lee', 'n'], ['sanbek', 'n']],
#  [['drama', 'n'], ['officials', 'n']],
#  [['korean', 'a'], ['media', 'n']],
#  [['scriptwriter', 'n']],
#  [['moon', 'n']],
#  [['positive', 'a'], ['attitude', 'n']],
#  [['possibilities', 'n']],
#  [['season', 'n']],
#  [['production', 'n'], ['teams', 'n']],
#  [['cast', 'n'], ['members', 'n']],
#  [['than', 'n'], ['90', 'n'], ['%', 'n']],
#  [['time', 'n']],
#  [['concrete', 'a'], ['discussions', 'n']],
#  [['kang', 'n'], ['teo', 'n']],
#  [['role', 'n']],
#  [['lee', 'n'], ['juno', 'n']],
#  [['big', 'a'], ['break', 'n']],
#  [['work', 'n']],
#  [['office', 'n']],
#  [['man', 'n']],
#  [['creation', 'n']],
#  [['concrete', 'n']],
#  [['content', 'n']],
#  [['content', 'n']],
#  [['instagram/@channel.ena.d', 'n']],
#  [['kang', 'v'], ['gi-yeon', 'n']],
#  [['role', 'n']],
#  [['boss', 'n'], ['jung', 'n'], ['myeong-suk', 'n']],
#  [['u-young', 'a'], ['woo', 'n']],
#  [['interview', 'n']],
#  [['korean', 'a'], ['media', 'n']],
#  [['willingness', 'n']],
#  [['.', 'n'], ['instagram', 'n']],
#  [['season', 'n']],
#  [['atmosphere', 'r']],
#  [['drama', 'n'], ['shooting', 'v'], ['site', 'n']],
#  [['feeling', 'v']],
#  [['course', 'n']],
#  [['end', 'n']],
#  [['appearance', 'n']],
#  [['ju', 'n'], ['jong', 'n'], ['hyuk', 'n']],
#  [['good', 'a'], ['colleague', 'n']],
#  [['kwon', 'n'], ['minu', 'n']],
#  [['rivalry', 'n']],
#  [['radio', 'n']],
#  [['19th', 'n']],
#  [['possibility', 'n']],
#  [['season', 'n']],
#  [['_', 'n']],
#  [['final', 'a'], ['script', 'n']],
#  [['season', 'n']],
#  [['work', 'n']],
#  [['web', 'n'], ['comics', 'n']],
#  [['musicals', 'n']],
#  [['sequel', 'n']],
#  [['cast', 'n']],
#  [['season', 'n']],
#  [['article', 'n']],
#  [["'s", 'n']],
#  [['reaction', 'n']],
#  [['u', 'n']],
#  [['-yong-woo', 'n']],
#  [['genius', 'n']],
#  [['skin', 'n'], ['kang', 'v'], ['gi-yeon', 'a'], ['response', 'n']],
#  [['work', 'n']],
#  [['kstyle9/1', 'n']],
#  [['thu', 'n']],
#  [['kang', 'n'], ['teo', 'n']],
#  [['september', 'n']],
#  [['enlistment', 'n']],
#  [['fan', 'n'], ['meeting', 'n']],
#  [['u-yong-woo', 'a']],
#  [['genius', 'n'], ['skin', 'n']],
#  [['army', 'n'], ['kstyle9/1', 'n']],
#  [['(thu)', 'r'], ['9:36', 'n'], ['kstyle9/5', 'n']],
#  [['korean', 'a'], ['dora', 'n'], ['u-yong-woo', 'a']],
#  [['genius', 'n']],
#  [['skin', 'n'], ['global', 'a'], ['1st', 'n'], ['place', 'n']],
#  [['encount8/31', 'n']],
#  [['20:13', 'n'], ['chubby', 'n']],
#  [['short', 'a'], ['stature', 'n']],
#  [['armpit', 'n'], ['hair', 'n']],
#  [['fashion', 'n'], ['magazines', 'n']],
#  [['models', 'n']],
#  [['diversity', 'n'], ['era', 'n']],
#  [['subdivision', 'n']],
#  [['diversity', 'n'], ['erika', 'n'], ['toda', 'n']],
#  [['actress', 'n'], ['absence', 'n']],
#  [['next', 'a'],
#   ["year's", 'n'],
#   ['january', 'a'],
#   ['dora', 'n'],
#   ['return', 'v'],
#   ['theory', 'n']],
#  [['certain', 'a'], ['circumstances', 'n']],
#  [['real', 'a'], ['face', 'n'], ['shot', 'n']],
#  [['gold', 'n'],
#   ['bomb', 'n'],
#   ['/', 'n'],
#   ['barrel', 'n'],
#   ['sake', 'n'],
#   ['buns', 'n']],
#  [['glasses', 'n']],
#  [['perm', 'n']],
#  [['extremely', 'r'], ['handsome', 'a'], ['beautiful', 'a'], ['line', 'n']],
#  [['<megumi', 'n'], ['matsumoto', 'n']],
#  [['time', 'n']],
#  [['marriage', 'n']],
#  [['yuzo', 'n'], ["kayama's", 'v'], ['wife', 'n']],
#  [['letter', 'n']],
#  [['female', 'n'], ['fans', 'n']],
#  [['couple', 'n'], ['popular', 'a'], ['cup', 'n'], ['noodles', 'n']],
#  [["tetsuko's", 'n'], ['room', 'n'], ['human', 'n']],
#  [['food', 'n']],
#  [['egashira', 'n']],
#  [['bad', 'a'], ['reputation', 'n']],
#  [['co-star', 'a'], ['line', 'n'], ['block', 'n']],
#  [['toyota', 'n']],
#  [['teruyuki', 'n'],
#   ["kagawa's", 'v'],
#   ['another', 'n'],
#   ['dangerous', 'a'],
#   ['face', 'n']],
#  [['child-rearing', 'n'], ['child', 'n']],
#  [['school', 'n']],
#  [['word', 'n']],
#  [['the', 'n'], ['son', 'n']],
#  [['shou', 'a'], ['fuku-kun', 'n']],
#  [['crying', 'v']],
#  [['reason', 'n']],
#  [['reason', 'n']],
#  [['reason', 'n']],
#  [['reason', 'n']],
#  [['reason', 'n']],
#  [['reason', 'n']],
#  [['face', 'n']],
#  [['face', 'n']],
#  [['teen', 'n']],
#  [['nanase', 'n'], ['aikawa', 'n']],
#  [['college', 'n'], ['student', 'n']],
#  [['age', 'n']],
#  [['end', 'n']],
#  [['year]', 'n'], ['junju', 'n'], ['/', 'n'], ['ryohei', 'n'], ['odai', 'n']],
#  [['new', 'a'], ['member', 'n']],
#  [['one-word', 'a'], ['turtle', 'n']],
#  [['yanus', 'n']],
#  [["switzerland's", 'a'], ['natural', 'a'], ['history', 'n'], ['museum', 'n']],
#  [['[marriage', 'n']],
#  [['jun', 'n'], ['idida', 'n']],
#  [['hachiya', 'n'], ['yanami', 'n'], ['sns', 'n']],
#  [['anyone', 'n']],
#  [['person', 'n']],
#  [['only', 'r'], ['sexual', 'a'], ['harassment', 'n']],
#  [['assault', 'n']],
#  [['power', 'n'], ['harassment', 'n']],
#  [['kagawa', 'n']],
#  [['real', 'a'], ['face', 'n']],
#  [['330', 'n'], ['yen', 'n']],
#  [['tax', 'n']],
#  [['330', 'n'], ['yen', 'n'], ['storm', 'n']],
#  [['aiba', 'n']],
#  [['tv', 'n'], ['animal', 'n'], ['protection', 'n'], ['organization', 'n']],
#  [['full', 'a'], ['sentence', 'n']],
#  [['110', 'n'], ['yen', 'n']],
#  [['tax', 'n'], ['kaoru', 'n'], ['yachigusa', 'n']],
#  [['girl', 'n']],
#  [['sense', 'n']],
#  [['life', 'n']],
#  [['heroine', 'n']],
#  [['hayao', 'n'], ['miyazaki', 'n']],
#  [['heroine', 'n']],
#  [['hayao', 'n'], ['miyazaki', 'n']],
#  [['defective', 'a'], ['house', 'n'], ['leopalace', 'n']],
#  [['home', 'n'], ['appliances', 'n']],
#  [['suzuki', 'n'], ['suzuki', 'n']],
#  [['suzuki', 'n'], ['toshio', 'n']],
#  [['110', 'n'], ['yen', 'n']],
#  [['tax', 'n']],
#  [['assault', 'n'], ['video', 'n']],
#  [['power', 'n'], ['harassment', 'n'], ['sanyo', 'n']],
#  [['sanyo', 'n']],
#  [['newcomer', 'a'], ['male', 'n'], ['ana', 'n']],
#  [['naked', 'a'], ['dance', 'n']],
#  [['110', 'n'], ['yen', 'n']],
#  [['tax', 'n'], ['copyright', 'n']],
#  [['©', 'n'], ['2022', 'n'], ['hearst', 'n'], ['fujingaho', 'n']],
#  [['unauthorized', 'a'], ['reproduction', 'n']]]

# %%
from nltk.stem import WordNetLemmatizer

lemma = WordNetLemmatizer()
result = []
for texts in test:
    keyword = ""
    for text in texts:
        keyword += lemma.lemmatize(text[0],text[1]) + " "
#         print(lemma.lemmatize(text[0],text[1]))
    result.append(keyword.strip())

# %%
result
# Out:
# ['synopsis',
#  'rich woman',
#  'south korea',
#  'south korea',
#  'dda',
#  'son ye jin',
#  'hyun bin',
#  'efficient quota',
#  'streamingprofil korean drama drama crash',
#  'broadcast schedule',
#  'link',
#  'drakor',
#  'interesting information',
#  'lover',
#  'romantic comedy series',
#  'series',
#  'hyun bin',
#  'son ye jin',
#  'husband',
#  'wife',
#  'profile',
#  'korean drama player',
#  'spotlight',
#  'prime minister',
#  'prime minister',
#  'love',
#  'reporter',
#  'yoona snsdnamun',
#  'synopsis',
#  'drama',
#  'mydramalist',
#  'broadcast schedule',
#  'drakor.crash landing',
#  'figure',
#  'yoon se ri',
#  'woman',
#  'south korea',
#  'many business',
#  'young age.one day',
#  'accident',
#  'north korean area',
#  'tree',
#  'ri jeong hyeok',
#  'hyun bin',
#  'soldier',
#  'son',
#  'north korean official',
#  'jeong hyeok',
#  'yoon se ri',
#  'even jeong hyeok',
#  'men',
#  'jeong hyeok',
#  'arrange marriage',
#  'north korean conglomerate daughter',
#  'seo',
#  '(seo ji hye',
#  "se ri's candidate",
#  'namely gu seung jung',
#  'kim jung hyun',
#  'north korea',
#  'fraud',
#  'step sister',
#  'ri.viral mumun film',
#  'true story',
#  'complete synopsis',
#  'mumun film',
#  'true story',
#  'complete synopsis',
#  'orphanage child',
#  'north sulawesi',
#  'bud',
#  'priest',
#  'board',
#  'pantithe story',
#  'flower',
#  'orphan victim',
#  'harassment',
#  'orphanage priest',
#  'north dirikorea',
#  '100 thousand troop',
#  'russia',
#  'war',
#  'ukrainasurati kim jong un',
#  'leader',
#  'donetsk',
#  'cooperation',
#  'north korea',
#  'bilateraltin relation',
#  'russia',
#  'north',
#  'art worker',
#  'age',
#  '30 year',
#  'politician',
#  '7 irregularity',
#  'finding',
#  'national human right commission',
#  'sexual harassment',
#  'princess candraikhi',
#  'lpsk',
#  'kuasacuma brigadier j relationship',
#  'private room',
#  "ferdy sambo's house",
#  'lpsk',
#  'batang toll road',
#  '7 minibus passenger',
#  'truck driver',
#  'ppsu officer',
#  'breast cancer',
#  'child',
#  'nylanu',
#  'road',
#  'body',
#  'male corpse',
#  'trench',
#  'day',
#  'beforeeventsweb5-superball']

# %%
import json
import os
import sys
import urllib.request
client_id = "6yrWrXVyj5VaRKnqi_fv"
client_secret = "i9h16BCiqz"

url = "https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

def translate(str):
    encText = urllib.parse.quote(str)
    data = "source=en&target=ko&text=" + encText
    response = urllib.request.urlopen(request, data=data.encode("utf-8"))
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        result = json.loads(response_body.decode('utf-8'))
        return result['message']['result']['translatedText']
#         print(result['message']['result']['translatedText'])
    #     print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)

# %%
translate("squid game. prospect. red light. green light. nerve-shredding terror. fond childhood memory. alone.the korean thriller. story. debt-ridden people. huge cash prize. deadly series. children's game. 111 million user. bridgerton. top spot. korean drama. green light. audience. rise. other k-dramas. new convert")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 translate("squid game. prospect. red light. green light. nerve-shredding terror. fond childhood memory. alone.the korean thriller. story. debt-ridden people. huge cash prize. deadly series. children's game. 111 million user. bridgerton. top spot. korean drama. green light. audience. rise. other k-dramas. new convert")
#
# Input In [91], in translate(str)
#      14 encText = urllib.parse.quote(str)
#      15 data = "source=en&target=ko&text=" + encText
# ---> 16 response = urllib.request.urlopen(request, data=data.encode("utf-8"))
#      17 rescode = response.getcode()
#      18 if(rescode==200):
#
# File ~\anaconda3\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\anaconda3\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~\anaconda3\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File ~\anaconda3\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File ~\anaconda3\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~\anaconda3\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
str = "u-yongu \n squid game. prospect. red light. green light. nerve-shredding terror. fond childhood memory. alone.the korean thriller. story. debt-ridden people. huge cash prize. deadly series. children's game. 111 million user. bridgerton. top spot. korean drama. green light. audience. rise. other k-dramas. new convert"

# %%
translator = googletrans.Translator() # 번역하는 함수
translator.translate(str, src='en', dest='ko').text
# Out:
# 'U-Yongu.오징어 게임.전망.빨간불.초록불.신경 분쇄 테러.어린 시절 기억을 좋아합니다.한국 스릴러.이야기.빚을지고있는 사람들.거대한 상금.치명적인 시리즈.어린이 게임.1 억 1,100 만 명의 사용자.브리거 턴.최고점.한국 드라마.초록불.청중.증가.다른 K- 드라마.새로운 변환'

# %%
txt = "\n".join(result)

print(translator.translate(txt, src='en', dest='ko').text)
# Out:
# 웹 사이트
# 자바 스크립트
# 웹 브라우저
# K- 드라마
# 이야기
# 북한
# 진행중인 전쟁
# 두 나라
# 놀라운 상징적 인 시리즈
# hallyu
# 일견
# 삶
# 북한
# 롬콤
# 스릴러 시리즈
# 5 K-Dramas 기능 스토리
# 북쪽
# 대한민국
# 넷플릭스
# 한국 리메이크
# 스페인 시리즈를 쳤다
# 라 카사 데 파펠
# 돈 습격
# Álex Pina
# 5 번의 성공적인 시즌
# 티비 쇼
# 돈 습격
# 한국 - 공동 경제 지역
# 유 지 테
# 교수
# 베를린
# 전종 서
# 도쿄
# 한국 리메이크
# 인질 위기
# 인질로부터 반도
# 직원
# 갱 멤버
# 조차 태스크 포스
# 북쪽
# 남쪽
# 첫 번째 부분
# 6 에피소드
# 6월
# 돈 습격
# 한국 - 공동 경제 지역
# 마지막 분기
# 강의
# 개요
# K- 드라마
# 북한의 이야기
# 불시착
# 아들 Ye Jin
# 현 빈
# 대부분의 과장된 시리즈
# 드라마
# 이야기
# 한국 상속인 윤 세리
# 아들 Ye Jin
# DMZ
# 한반도
# 북한 군인
# Ri Jung Hyuk 선장
# 고향
# 도전
# 긴장
# 두 나라
# 윤 세리
# 캡틴 리
# 이승
# 지
# Jo Jung Suk
# 2012 롬콤 k
# 드라마
# 왕
# 2 하트
# 협동
# 영향력있는 두 사람
# 북한
# 대한민국
# Ha ha ha woon
# 역할
# 북한의 엘리트 특수 부대 강사
# 딸
# 고위 군사 공무원
# 공동 군사 협력
# 한국의 왕자
# 이재
# 사랑 증오 관계
# 듀오
# 힘든 상황
# 사랑
# 충의
# 또 다른 2012 K- 드라마
# 이야기
# 두 카운티
# 한국 과학자 Seo Myung Joon
# 사랑
# 북한 과학자
# 진 전
# 김정은
# 이종 수크
# 파크 헌
# 천재 심장 외과 의사
# 북한
# 어린이
# 아버지
# 북한
# 의사
# 새로운 나라
# 사건
# 대한민국
# 최상위 병원
# 대학 병원
# Kdrama 스타 이메일 업데이트

# %%
print(translate(txt))
# Out:
# 웹사이트
# 자바스크립트
# 웹 브라우저
# k-back의
# 이야기
# 북한
# 진행 중인 전쟁
# 두 나라
# 주목할 만한 상징적인 시리즈
# 한류
# 잠깐보다
# 인생
# 북한
# 롬콤의
# 스릴러 시리즈
# 5k급 특집 기사
# 북쪽
# 대한민국.
# 넷플릭스
# 한국판 리메이크
# 스페인 시리즈를 히트시키다
# 라카사드 종이
# 돈을 강탈하다
# 알레스피나
# 다섯 번의 성공적인 시즌
# 텔레비전 쇼
# 돈을 강탈하다
# 한국과 공동 경제 지역
# 유지태
# 교수님
# 베를린의
# 전종서
# 東京의
# 한국판 리메이크
# 인질극
# 인질로부터 반도.
# 직원
# 갱단원
# 짝수 태스크포스
# 북쪽
# 남쪽
# 제1부
# 6화
# 6월.
# 돈을 강탈하다
# 한국과 공동 경제 지역
# 최종 분기
# 코스
# 고갈시키다
# k-back의
# 북남 이야기
# 불시착
# 손예진
# 현빈
# 가장 과장된 급수
# 연극하다
# 이야기
# 한국의 상속녀 윤세리
# 손예진
# dmz
# 한반도
# 북한군
# 대장 리정혁
# 고향
# 도전
# 긴장
# 두 나라
# 윤세리
# 대위리
# 이승
# 지
# 조정숙
# 2012년 롬콤
# 연극하다
# 왕
# 하트 2개
# 공동 작업
# 영향력 있는 두 사람
# 북한
# 대한민국.
# 하지운
# 역할.
# 북한의 정예 특수부대 교관
# 딸.
# 군 고위 관리
# 합동 군사 협력
# 한국의 왕세자
# 이재
# 애증 관계
# 2인조
# 어려운 상황
# 사랑하다
# 충성심
# 또 다른 2012년 한국 드라마
# 이야기
# 두 군
# 한국의 과학자 서명준
# 사랑하다
# 북한 과학자
# 진재
# 김정은
# 이종석
# 박훈
# 천재 심장외과 의사
# 북한
# 어린아이
# 아버지.
# 북한
# 의사선생님.
# 신흥국
# 사건
# 대한민국.
# 일류 병원
# 대학 병원
# kdrama star 이메일 업데이트

# %%
# Out:
# 가해자
# 영화
# 우타 마루
# 문제
# 영화
# 선물
# 중요한 사람들
# 재난 예방 [비상 지원
# 파키스탄 홍수 피해
# 올바른 지식
# 준비
# 대피 훈련
# 태풍
# 폭우
# 3 분 키워드
# 많은 쿠폰
# ID
# 자바 스크립트
# 함수
# 야후
# 소식
# 자바 스크립트 설정
# 자바 스크립트 설정
# 8/19 (Fri) 19:20 분포
# 새로운 변호사
# 자폐 스펙트럼
# 큰 반응
# 일본
# 훌륭한 응답
# 일본
# 드라마
# 유
# -
# yongu
# 천재 피부
# [사진
# 인기있는 한국 여배우
# 이것
# 일하다
# 최대 잠재 고객 등급
# 17.5 %
# 팔월
# 가능성
# 계절
# 스포일러
# 기사
# 보고서
# 한국 매체
# 팔월
# 이 산 벡
# 대표
# 이야기
# 제조업 회사
# U-Yong-woo
# 천재 피부
# 계절
# 가능성
# 계속
# 일정
# 깁스
# 생산 팀
# 논의
# 목표
# 90 %
# 승무원
# 큰 변화
# 주목
# 인스 타 그램
# /@booboo2injo Lee Sanbek
# 드라마 공무원
# 한국 매체
# 대본 작자
# 달
# 긍정적 인 태도
# 가능성
# 계절
# 생산 팀
# 캐스트 멤버
# 90 % 이상
# 시각
# 구체적인 토론
# 강 테오
# 역할
# 이 주노
# 큰 휴식
# 일하다
# 사무실
# 남성
# 창조
# 콘크리트
# 콘텐츠
# 콘텐츠
# Instagram/@channel.ena.d
# 강 지연
# 역할
# Bos Jung Myeong-Suk
# U-young woo
# 회견
# 한국 매체
# 쾌히 하기
# . 인스 타 그램
# 계절
# 대기
# 드라마 촬영 사이트
# 느끼다
# 강의
# 끝
# 모습
# Ju Jong Hyuk
# 좋은 동료
# Kwon Minu
# 경쟁
# 라디오
# 19 일
# 가능성
# 계절
# _
# 최종 스크립트
# 계절
# 일하다
# 웹 만화
# 뮤지컬
# 계속
# 깁스
# 계절
# 기사
# '에스
# 반응
# 유
# -성우
# 천재
# 피부 강 기금 반응
# 일하다
# Kstyle9/1
# thu
# 강 테오
# 구월
# 입대
# 팬 미팅
# U-Yong-woo
# 천재 피부
# 군대 Kstyle9/1
# (Thu) 9:36 Kstyle9/5
# 한국 도라 우용우
# 천재
# 스킨 글로벌 1 위
# Account8/31
# 20:13 통통한
# 단신
# 겨드랑이 털
# 패션 잡지
# 모델
# 다양성 시대
# 재분
# 다양성 에리카 토다
# 여배우 부재
# 내년 1 월 도라 반환 이론
# 특정 상황
# 진짜 페이스 샷
# 금 폭탄 / 배럴 술 롤빵
# 유리
# 파마
# 매우 잘 생긴 아름다운 선
# <메 구미 마츠모토
# 시각
# 결혼
# 유조 카야마의 아내
# 편지
# 여성 팬
# 인기있는 컵 국수 커플
# 테츠 코의 방 인간
# 음식
# 에 가시라
# 나쁜 평판
# 공동 스타 라인 블록
# 도요타
# 카가와 테루 요키의 또 다른 위험한 얼굴
# 어린이 재배치 아이
# 학교
# 단어
# 아들
# Shou Fuku-kun
# 울다
# 이유
# 이유
# 이유
# 이유
# 이유
# 이유
# 얼굴
# 얼굴
# 비탄
# 나나 세나 아이 카와
# 대학생
# 나이
# 끝
# 연도] Junju / Ryohei Odai
# 새로운 회원
# 한 단어 거북
# 야누스
# 스위스의 자연사 박물관
# [결혼
# Jun Idida
# 하치야 야나미 SN
# 누구나
# 사람
# 성희롱 만
# 폭행
# 파워 괴롭힘
# 카가와
# 진짜 얼굴
# 330 엔
# 세
# 330 엔 폭풍
# 아이바
# TV 동물 보호 조직
# 전체 문장
# 110 엔
# 세금 kaoru yachigusa
# 여자
# 감각
# 삶
# 여걸
# 하야오 미야자키
# 여걸
# 하야오 미야자키
# 결함이있는 집 표현
# 가정 기기
# 스즈키 스즈키
# 스즈키 토시오
# 110 엔
# 세
# 폭행 비디오
# 파워 괴롭힘 Sanyo
# Sanyo
# 새로 온 남성 아나
# 알몸 춤
# 110 엔
# 세금 저작권
# © 2022 Hearst Fujingaho
# 무단 재생산

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk import RegexpParser
from nltk import Tree
import nltk
import re
import pandas as pd
import spacy
from konlpy.tag import Okt
from nltk.corpus import stopwords
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
import googletrans
import pyautogui
import time
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

#python -m spacy download ja_core_news_sm
#ja_core_news_sm
nlp = spacy.load("ko_core_news_sm")

def news(news_urls):
    translator = googletrans.Translator()
    for url_no in news_urls:
        print(url_no)
        # driver = webdriver.Chrome()
        driver.get(url_no)

        pyautogui.hotkey('shift', 'F10')
        for i in range(8):
            pyautogui.hotkey('down')
        pyautogui.hotkey('enter')

        time.sleep(1)

        for c in range(0,5):
            driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.PAGE_DOWN)
            time.sleep(1)

        html = driver.page_source
        soup = BeautifulSoup(html)

        str = ""
        str2 = ""
        result = ""
        for text in soup.findAll("p"):

            str += text.get_text() + "\n"
            str2 += text.get_text() + "\n"
        #     if(len(str)>1000):
        #         # result1 = translator.translate(str, dest='ko')
        #         result += str
        #         str = ""

        # if str !="":
        #     # result1 = translator.translate(str, dest='ko')
        #     result += result1.text.replace(" -", "-").replace("- ", "-")
            result += str
            str = ""

        return result



def np_tag(text):
    #text = re.sub('[^a-zA-Z]', ' ', text)
    #text = text.lower()
    
    hannanum = Okt()
    df = pd.DataFrame(columns = ['CHUNK'])
    doc = hannanum.nouns(text)
    news_desc = '\n'.join(doc)

    # doc = nlp(text)
    # # for chunk in doc.noun_chunks:
    # #    df = df.append({'CHUNK': chunk.text}, ignore_index=True)
    # for token in doc:
    #    print(token.text, token.pos_, token.dep_)

    return news_desc

# %%
driver = webdriver.Chrome()
# driver.get("https://www.teamtalk.com/tottenham-hotspur/son-heung-min-not-taken-richarlison-arrival-well-pundit-antonio-conte-big-problem")

testnews = ['https://www.goal.com/jp/%E3%83%AA%E3%82%B9%E3%83%88/from-heung-min-son-to-kai-havertz-how-bayer-leverkusen-made/bltaab0891b0db9583f']
wl =np_tag(news(testnews))
#wl=np_tag("Actors and actresses who are the “leading actors” are absolutely indispensable in Korean dramas.")
# no_capitals = wl.values.tolist()
#print(no_capitals)
#stops = set(stopwords.words('english'))
#print(no_capitals)

print(wl)


# testnews = ['https://www.kdramastars.com/articles/126325/20220820/k-dramas-north-south-korea-money-heist-korea-crash-landing-on-you.htm']
# wl =np_tag(news(testnews))
# #wl=np_tag("Actors and actresses who are the “leading actors” are absolutely indispensable in Korean dramas.")
# # no_capitals = wl.values.tolist()
# #print(no_capitals)
# #stops = set(stopwords.words('english'))
# #print(no_capitals)

# print(wl)


# testnews = ['https://www.football.london/tottenham-hotspur-fc/transfer-news/tottenham-son-conte-ndombele-transfer-24937341']
# wl =np_tag(news(testnews))
# #wl=np_tag("Actors and actresses who are the “leading actors” are absolutely indispensable in Korean dramas.")
# #print(no_capitals)
# #stops = set(stopwords.words('english'))
# #print(no_capitals)

# print(wl)

driver.quit()

# stemmer = nltk.stem.SnowballStemmer('english')

#testmemo =""
# f = open("C:/Users/multicampus/Desktop/test/test.txt", 'w', encoding='utf-8')
# for no_capital in no_capitals:
#     no_stops = [word for word in no_capital if not word in stops]
#     for tmp in no_stops:
#         #testmemo=testmemo+tmp+'\n'
#         f.write(tmp+'\n')
# f.close()
# Out:
# https://www.goal.com/jp/%E3%83%AA%E3%82%B9%E3%83%88/from-heung-min-son-to-kai-havertz-how-bayer-leverkusen-made/bltaab0891b0db9583f
# 레버쿠젠
# 재능
# 젊은이
# 대부분
# 유럽
# 빅클럽
# 매각
# 발판
# 평판
# 높이
# 만약
# 커리어
# 업
# 노리
# 진기
# 예의
# 탤런트
# 라면
# 레버쿠젠
# 선택
# 일
# 것
# 레버쿠젠
# 활약
# 인정
# 돈
# 이적
# 선수
# 적지
# 레버쿠젠
# 타이틀
# 차례차례
# 획득
# 수
# 챔피언스리그
# 단골
# 로서
# 선수
# 유럽
# 최대
# 무대
# 정기
# 자신
# 시험
# 기회
# 레버쿠젠
# 방출
# 선수
# 상위
# 명
# 중
# 명
# 세
# 이하
# 하칸
# 놀
# 손흥민
# 카이
# 하바
# 츠
# 등
# 레버쿠젠
# 선수
# 지명도
# 선수
# 시즌
# 최대
# 판매
# 적금
# 총
# 매각
# 이익
# 루카스
# 아라리
# 오
# 유로
# 유로
# 레온
# 베
# 일리
# 카이
# 하바
# 츠
# 율리
# 안
# 브란트
# 베른
# 토
# 레노
# 하칸
# 놀
# 크리스토프
# 머
# 송흥민
# 유로
# 엠레
# 장
# 앙드레
# 슐레
# 레나토
# 아우
# 스트
# 유로
# 알투
# 비달
# 패
# 트릭
# 헤르메스
# 백만
# 테오
# 파
# 니스
# 게카스
# 파울
# 플로
# 유로
# 후안
# 유로
# 유로
# 디
# 탈
# 바토
# 프
# 엠마누엘
# 포
# 테츠
# 유로
# 루시오
# 바스티안
# 쇼
# 오프
# 제로
# 벨트
# 유로
# 로베르토
# 코바치
# 유로
# 유로
# 에머슨
# 총
# 대략
# 에머슨
# 로마
# 이적
# 것
# 레버쿠젠
# 약
# 매각
# 기록
# 이
# 브라질인
# 전
# 레미오
# 유로
# 지불
# 것
# 그
# 투자
# 대해
# 실로
# 수익
# 것
# 에머슨
# 로마
# 유벤투스
# 밀란
# 레알
# 마드리드
# 등
# 이탈리아
# 스페인
# 리그
# 타이틀
# 획득
# 경력
# 벤자민
# 헨릭스
# 레버쿠젠
# 유스
# 톱
# 팀
# 플레이
# 후
# 모나코
# 이적
# 클럽
# 정돈
# 금액
# 후
# 라이프치히
# 분데스리가
# 복귀
# 당초
# 렌탈
# 이적
# 이후
# 라이프치히
# 유로
# 이적
# 실현
# 우리
# 소셜
# 미디어
# 기능
# 제공
# 데이터
# 분석
# 및
# 사이트
# 올바로
# 동작
# 개인화
# 콘텐츠
# 광고
# 제공
# 위해
# 쿠키
# 사용
# 회사
# 사이트
# 대한
# 귀하
# 사용
# 정보
# 회사
# 소셜
# 미디어
# 광고
# 및
# 분석
# 협력
# 공유
# 이
# 쿠키
# 웹사이트
# 기능
# 위해
# 필수
# 회사
# 시스템
# 내
# 종료
# 수
# 이
# 쿠키
# 개인정보
# 선호
# 로그인
# 양식
# 작성
# 서비스
# 요청
# 해당
# 귀하
# 행위
# 따라서
# 주로
# 설정
# 귀하
# 브라우저
# 이
# 쿠키
# 차단
# 거나
# 쿠키
# 대해
# 알림
# 설정
# 수
# 이
# 경우
# 해당
# 사이트
# 일부
# 기능
# 동작
# 수
# 이
# 쿠키
# 방문자
# 수
# 데이터
# 트래픽
# 정보
# 확인
# 회사
# 사이트
# 성능
# 측정
# 개선
# 수
# 또한
# 가장
# 인기
# 인기
# 페이지
# 확인
# 방문자
# 사이트
# 이동
# 방법
# 확인
# 수
# 쿠키
# 수집
# 모든
# 정보
# 누적
# 익명
# 처리
# 쿠키
# 허용
# 귀하
# 회사
# 사이트
# 방문
# 시기
# 알
# 수
# 쿠키
# 동영상
# 및
# 실시간
# 채팅
# 고급
# 기능
# 개인화
# 허용
# 쿠키
# 회사
# 회사
# 페이지
# 추가
# 제
# 서비스
# 사업자
# 설정
# 수
# 쿠키
# 허용
# 일부
# 기능
# 정상
# 작동
# 수
# 이
# 쿠키
# 회사
# 광고
# 협력
# 사가
# 회사
# 사이트
# 설정
# 것
# 해당
# 협력
# 귀하
# 관심사
# 대한
# 프로파일
# 다른
# 사이트
# 관련
# 광고
# 표시
# 위해
# 이
# 쿠키
# 사용
# 이
# 쿠키
# 귀하
# 브라우저
# 기기
# 식별
# 함
# 동작
# 이
# 쿠키
# 허용
# 다른
# 웹사이트
# 회사
# 제공
# 맞춤
# 광고
# 경험
# 수
# 이
# 쿠키
# 회사
# 콘텐츠
# 귀하
# 친구
# 네트워크
# 공유
# 수
# 사이트
# 추가
# 일부
# 소셜
# 미디어
# 서비스
# 설정
# 것
# 이
# 쿠키
# 여러
# 사이트
# 귀하
# 브라우저
# 추적
# 수
# 귀하
# 관심
# 영역
# 프로파일
# 수
# 귀하
# 방문
# 다른
# 웹사이트
# 콘텐츠
# 메시지
# 영향
# 수
# 쿠키
# 허용
# 공유
# 도구
# 사용
# 못
# 거나
# 확인
# 수

# %%
wl
# Out:
# '토트넘\n이번\n여름\n점검\n것\n이적\n연결\n콘테\n이번\n시즌\n변화\n계획\n것\n것\n증명\n콘테\n토트넘\n선\n수\n스토리\n무료\n토트넘\n뉴스레터\n가입\n더\n뉴스레터\n토트넘\n입\n안토니오\n콘테\n자신\n팀\n구축함\n조화\n노스\n런더너스\n이번\n시즌\n것\n조언\n인상\n형태\n출발\n현재\n리그\n위\n차지\n이제\n또한\n최근\n몇\n주\n동안\n이\n인상\n모습\n그\n입\n그\n측면\n중심\n무대\n서기\n시작\n토요일\n풀럼\n경기\n승리\n때\n출발\n불구\n브라질\n셔츠\n이번\n시즌\n지금\n입\n중\n가장\n효과\n것\n입증\n더\n보기\n훈련\n투쟁\n및\n대해\n말\n모든\n단어\n과\n군\n합류\n및\n영향\n측면\n통합\n눈\n은\n과\n유망\n관계\n구축\n의\n감독\n그\n향상\n수\n경험\n윙백\n팀\n보유\n이탈리아\n선수\n이번\n시즌\n개선\n집중\n격차\n잉글랜드\n승리\n위해\n것\n것\n알\n우리\n지난\n시즌\n경쟁력\n개선\n위해\n노력\n고\n인정\n것\n우리\n목표\n만약\n당신\n나\n시티\n리버풀\n대해\n내\n대답\n우리\n수년\n동안\n코치\n일\n세계\n최고\n두\n클럽\n대해\n이야기\n것\n전\n인터밀란\n첼시\n감독\n이번\n시즌\n그\n이상\n만약\n토트넘\n스쿼드\n서로\n적응\n수\n지난\n시즌\n발전\n것\n다음\n유망\n징후\n주말\n풀럼\n전\n최선\n다해\n골\n못\n손흥민\n정규\n시간\n퇴장\n벤치\n좌절\n고립\n모습\n골\n한국\n국가대표\n선수\n첫\n경기\n득점\n못\n손흥민\n최상\n컨디션\n골문\n앞\n그\n운\n경기\n문제\n확인\n경기\n중\n뿐\n훈련\n세션\n마찬가지\n이탈리아\n사람\n말\n프레이저\n포스터\n훈련\n세션\n환상\n선방\n득점\n어려움\n것\n기간\n나\n계속\n걱정\n말\n써니\n포함\n내\n선수\n경기\n걱정\n때문\n나\n그\n이\n스트라이커\n골\n것\n것\n알\n팀\n방해\n토요일\n그\n구출\n벤치\n친구\n위로\n손흥민\n토트넘\n벤치\n맨\n끝\n홀로\n포스터\n보고\n손흥민\n옆\n부분\n이전\n대중\n눈\n토트넘\n선수\n간의\n긍정\n관계\n측면\n더욱이\n클럽\n경험\n선수\n계약\n음\n그\n선수\n캠페인\n선례\n포함\n여름\n실적\n시니어\n선수\n그룹\n이적\n후\n것\n여름\n나폴리\n임대\n이적\n프랑스인\n대해\n콘테\n그\n자질\n가지\n그\n그것\n팀\n것\n이해해\n그\n팀\n플레이\n포지션\n요구\n것\n것\n고\n말\n우리\n매우\n일\n그\n다른\n사람\n더\n일해\n그\n재능\n가지\n단일\n선수\n팀\n위해\n팀\n투입\n모든\n선수\n자신\n일\n모든\n선수\n경기장\n엉망\n것\n다음\n안토니오\n콘테\n이적\n마스터\n클래스\n풀럼\n이례\n토트넘\n결정\n강조\n토트넘\n뉴스\n챔피언스\n리그\n스쿼드\n혼란\n결정\n의\n전체\n토트넘\n프리미어\n리그\n일정\n목록'

# %%
capture_values = [
    ("item.namespace", "string"),
    ("item.title", "string"),
    ("item.text", "string")
]

def parse_namuwiki_json(limit = -1, debug=False):
    i = 0
    doc = {}
    with open(SOURCE_FILE) as f:
        for prefix, event, value in ijson.parse(f):
            if debug:
                print(prefix, event, value)

         \\\\ if (prefix, event) in capture_values:
            doc[prefix[5:]] = value
          if (prefix, event, value) == ("item", "end_map", None):
            yield doc    
            doc = {}
            i += 1

            if limit > 0 and i >= limit:
              break

for doc in parse_namuwiki_json(10, debug=False):
  print(doc['text'])
  print("===" * 10)
  doc['text'] = extract_text(doc['text'])
  print(doc['text'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [174], in <cell line: 26>()
#      23         if limit > 0 and i >= limit:
#      24           break
# ---> 26 for doc in parse_namuwiki_json(10, debug=False):
#      27   print(doc['text'])
#      28   print("===" * 10)
#
# Input In [174], in parse_namuwiki_json(limit, debug)
#       8 i = 0
#       9 doc = {}
# ---> 10 with open(SOURCE_FILE) as f:
#      11   for prefix, event, value in ijson.parse(f):
#      13     if debug:
#
# NameError: name 'SOURCE_FILE' is not defined
